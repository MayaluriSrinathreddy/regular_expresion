# %%
text="innomatics is &&one of the best institute%%% for data science????"
text.("&&& %%%")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 text="innomatics is &&one of the best institute%%% for data science????"
# ----> 2 text.remove("&&& %%%")
#
# AttributeError: 'str' object has no attribute 'remove'

# %%
text.replace("&","").replace("?","").replace("%","")
# Out:
# 'innomatics is one of the best institute for data science'

# %%
text="""Being one of the most powerful, and versatile programming languages, Python is easy to learn and is widely used among developers. Its popularity and demand is increasing ever since its launch and still continuing to grow. Demand for Python developers has increased by 41% in the last 5 years. Out of 25 million developers in the world, 8.2 million are Python developers. It is a must-have skill for programmers, data scientists, and developers across many industries. Python, being so popular and highly demanding is ranked as the top programming language, according to several reports."""

# %%
text
# Out:
# 'Being one of the most powerful, and versatile programming languages, Python is easy to learn and is widely used among developers. Its popularity and demand is increasing ever since its launch and still continuing to grow. Demand for Python developers has increased by 41% in the last 5 years. Out of 25 million developers in the world, 8.2 million are Python developers. It is a must-have skill for programmers, data scientists, and developers across many industries. Python, being so popular and highly demanding is ranked as the top programming language, according to several reports.'

# %%
import re

# %%
a=list(text)

# %%
a
# Out:
# ['B',
#  'e',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'o',
#  'n',
#  'e',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'm',
#  'o',
#  's',
#  't',
#  ' ',
#  'p',
#  'o',
#  'w',
#  'e',
#  'r',
#  'f',
#  'u',
#  'l',
#  ',',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'v',
#  'e',
#  'r',
#  's',
#  'a',
#  't',
#  'i',
#  'l',
#  'e',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'l',
#  'a',
#  'n',
#  'g',
#  'u',
#  'a',
#  'g',
#  'e',
#  's',
#  ',',
#  ' ',
#  'P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'e',
#  'a',
#  's',
#  'y',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'l',
#  'e',
#  'a',
#  'r',
#  'n',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'w',
#  'i',
#  'd',
#  'e',
#  'l',
#  'y',
#  ' ',
#  'u',
#  's',
#  'e',
#  'd',
#  ' ',
#  'a',
#  'm',
#  'o',
#  'n',
#  'g',
#  ' ',
#  'd',
#  'e',
#  'v',
#  'e',
#  'l',
#  'o',
#  'p',
# ...

# %%
##re.findall(pattern,text)

# %%
re.findall("\w\w",text)
# Out:
# ['Be',
#  'in',
#  'on',
#  'of',
#  'th',
#  'mo',
#  'st',
#  'po',
#  'we',
#  'rf',
#  'ul',
#  'an',
#  've',
#  'rs',
#  'at',
#  'il',
#  'pr',
#  'og',
#  'ra',
#  'mm',
#  'in',
#  'la',
#  'ng',
#  'ua',
#  'ge',
#  'Py',
#  'th',
#  'on',
#  'is',
#  'ea',
#  'sy',
#  'to',
#  'le',
#  'ar',
#  'an',
#  'is',
#  'wi',
#  'de',
#  'ly',
#  'us',
#  'ed',
#  'am',
#  'on',
#  'de',
#  've',
#  'lo',
#  'pe',
#  'rs',
#  'It',
#  'po',
#  'pu',
#  'la',
#  'ri',
#  'ty',
#  'an',
#  'de',
#  'ma',
#  'nd',
#  'is',
#  'in',
#  'cr',
#  'ea',
#  'si',
#  'ng',
#  'ev',
#  'er',
#  'si',
#  'nc',
#  'it',
#  'la',
#  'un',
#  'ch',
#  'an',
#  'st',
#  'il',
#  'co',
#  'nt',
#  'in',
#  'ui',
#  'ng',
#  'to',
#  'gr',
#  'ow',
#  'De',
#  'ma',
#  'nd',
#  'fo',
#  'Py',
#  'th',
#  'on',
#  'de',
#  've',
#  'lo',
#  'pe',
#  'rs',
#  'ha',
#  'in',
#  'cr',
#  'ea',
#  'se',
#  'by',
#  '41',
#  'in',
#  'th',
#  'la',
#  'st',
#  'ye',
#  'ar',
#  'Ou',
#  'of',
#  '25',
# ...

# %%
re.findall("\W",text)
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '%',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '-',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  ' ',
#  ',',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.']

# %%
text.split()
# Out:
# ['Being',
#  'one',
#  'of',
#  'the',
#  'most',
#  'powerful,',
#  'and',
#  'versatile',
#  'programming',
#  'languages,',
#  'Python',
#  'is',
#  'easy',
#  'to',
#  'learn',
#  'and',
#  'is',
#  'widely',
#  'used',
#  'among',
#  'developers.',
#  'Its',
#  'popularity',
#  'and',
#  'demand',
#  'is',
#  'increasing',
#  'ever',
#  'since',
#  'its',
#  'launch',
#  'and',
#  'still',
#  'continuing',
#  'to',
#  'grow.',
#  'Demand',
#  'for',
#  'Python',
#  'developers',
#  'has',
#  'increased',
#  'by',
#  '41%',
#  'in',
#  'the',
#  'last',
#  '5',
#  'years.',
#  'Out',
#  'of',
#  '25',
#  'million',
#  'developers',
#  'in',
#  'the',
#  'world,',
#  '8.2',
#  'million',
#  'are',
#  'Python',
#  'developers.',
#  'It',
#  'is',
#  'a',
#  'must-have',
#  'skill',
#  'for',
#  'programmers,',
#  'data',
#  'scientists,',
#  'and',
#  'developers',
#  'across',
#  'many',
#  'industries.',
#  'Python,',
#  'being',
#  'so',
#  'popular',
#  'and',
#  'highly',
# ...

# %%
re.findall("\w\w+",text)
# Out:
# ['Being',
#  'one',
#  'of',
#  'the',
#  'most',
#  'powerful',
#  'and',
#  'versatile',
#  'programming',
#  'languages',
#  'Python',
#  'is',
#  'easy',
#  'to',
#  'learn',
#  'and',
#  'is',
#  'widely',
#  'used',
#  'among',
#  'developers',
#  'Its',
#  'popularity',
#  'and',
#  'demand',
#  'is',
#  'increasing',
#  'ever',
#  'since',
#  'its',
#  'launch',
#  'and',
#  'still',
#  'continuing',
#  'to',
#  'grow',
#  'Demand',
#  'for',
#  'Python',
#  'developers',
#  'has',
#  'increased',
#  'by',
#  '41',
#  'in',
#  'the',
#  'last',
#  'years',
#  'Out',
#  'of',
#  '25',
#  'million',
#  'developers',
#  'in',
#  'the',
#  'world',
#  'million',
#  'are',
#  'Python',
#  'developers',
#  'It',
#  'is',
#  'must',
#  'have',
#  'skill',
#  'for',
#  'programmers',
#  'data',
#  'scientists',
#  'and',
#  'developers',
#  'across',
#  'many',
#  'industries',
#  'Python',
#  'being',
#  'so',
#  'popular',
#  'and',
#  'highly',
#  'demanding',
#  'is',
# ...

# %%
re.findall("\w*",text)
# Out:
# ['Being',
#  '',
#  'one',
#  '',
#  'of',
#  '',
#  'the',
#  '',
#  'most',
#  '',
#  'powerful',
#  '',
#  '',
#  'and',
#  '',
#  'versatile',
#  '',
#  'programming',
#  '',
#  'languages',
#  '',
#  '',
#  'Python',
#  '',
#  'is',
#  '',
#  'easy',
#  '',
#  'to',
#  '',
#  'learn',
#  '',
#  'and',
#  '',
#  'is',
#  '',
#  'widely',
#  '',
#  'used',
#  '',
#  'among',
#  '',
#  'developers',
#  '',
#  '',
#  'Its',
#  '',
#  'popularity',
#  '',
#  'and',
#  '',
#  'demand',
#  '',
#  'is',
#  '',
#  'increasing',
#  '',
#  'ever',
#  '',
#  'since',
#  '',
#  'its',
#  '',
#  'launch',
#  '',
#  'and',
#  '',
#  'still',
#  '',
#  'continuing',
#  '',
#  'to',
#  '',
#  'grow',
#  '',
#  '',
#  'Demand',
#  '',
#  'for',
#  '',
#  'Python',
#  '',
#  'developers',
#  '',
#  'has',
#  '',
#  'increased',
#  '',
#  'by',
#  '',
#  '41',
#  '',
#  '',
#  'in',
#  '',
#  'the',
#  '',
#  'last',
#  '',
#  '5',
#  '',
#  'years',
#  '',
#  '',
#  'Out',
#  '',
#  'of',
#  '',
# ...

# %%
re.findall("\d+",text)
# Out:
# ['41', '5', '25', '8', '2']

# %%
re.findall("\d*",text)
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
re.findall(".",text)
# Out:
# ['B',
#  'e',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'o',
#  'n',
#  'e',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  't',
#  'h',
#  'e',
#  ' ',
#  'm',
#  'o',
#  's',
#  't',
#  ' ',
#  'p',
#  'o',
#  'w',
#  'e',
#  'r',
#  'f',
#  'u',
#  'l',
#  ',',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'v',
#  'e',
#  'r',
#  's',
#  'a',
#  't',
#  'i',
#  'l',
#  'e',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'l',
#  'a',
#  'n',
#  'g',
#  'u',
#  'a',
#  'g',
#  'e',
#  's',
#  ',',
#  ' ',
#  'P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'e',
#  'a',
#  's',
#  'y',
#  ' ',
#  't',
#  'o',
#  ' ',
#  'l',
#  'e',
#  'a',
#  'r',
#  'n',
#  ' ',
#  'a',
#  'n',
#  'd',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'w',
#  'i',
#  'd',
#  'e',
#  'l',
#  'y',
#  ' ',
#  'u',
#  's',
#  'e',
#  'd',
#  ' ',
#  'a',
#  'm',
#  'o',
#  'n',
#  'g',
#  ' ',
#  'd',
#  'e',
#  'v',
#  'e',
#  'l',
#  'o',
#  'p',
# ...

# %%
text
# Out:
# 'Being one of the most powerful, and versatile programming languages, Python is easy to learn and is widely used among developers. Its popularity and demand is increasing ever since its launch and still continuing to grow. Demand for Python developers has increased by 41% in the last 5 years. Out of 25 million developers in the world, 8.2 million are Python developers. It is a must-have skill for programmers, data scientists, and developers across many industries. Python, being so popular and highly demanding is ranked as the top programming language, according to several reports.'

# %%
for i in text.split():
    if i.startswith("p") or i.startswith("P"):
        print(i)
# Out:
# powerful,
# programming
# Python
# popularity
# Python
# Python
# programmers,
# Python,
# popular
# programming

# %%
for i in text.split():
    if i[0]=="p":
        print(i)
# Out:
# powerful,
# programming
# popularity
# programmers,
# popular
# programming

# %%
re.findall(r"\bp\w+",text)
# Out:
# ['powerful',
#  'programming',
#  'popularity',
#  'programmers',
#  'popular',
#  'programming']

# %%
re.findall(r"\b[Pp]\w+",text)
# Out:
# ['powerful',
#  'programming',
#  'Python',
#  'popularity',
#  'Python',
#  'Python',
#  'programmers',
#  'Python',
#  'popular',
#  'programming']

# %%
re.findall(r"\b[aeiouAEIOU]\w+",text)
# Out:
# ['one',
#  'of',
#  'and',
#  'is',
#  'easy',
#  'and',
#  'is',
#  'used',
#  'among',
#  'Its',
#  'and',
#  'is',
#  'increasing',
#  'ever',
#  'its',
#  'and',
#  'increased',
#  'in',
#  'Out',
#  'of',
#  'in',
#  'are',
#  'It',
#  'is',
#  'and',
#  'across',
#  'industries',
#  'and',
#  'is',
#  'as',
#  'according']

# %%
re.findall(r"\b[^aeiouAEIOU\s\d\W]\w+",text)
# Out:
# ['Being',
#  'the',
#  'most',
#  'powerful',
#  'versatile',
#  'programming',
#  'languages',
#  'Python',
#  'to',
#  'learn',
#  'widely',
#  'developers',
#  'popularity',
#  'demand',
#  'since',
#  'launch',
#  'still',
#  'continuing',
#  'to',
#  'grow',
#  'Demand',
#  'for',
#  'Python',
#  'developers',
#  'has',
#  'by',
#  'the',
#  'last',
#  'years',
#  'million',
#  'developers',
#  'the',
#  'world',
#  'million',
#  'Python',
#  'developers',
#  'must',
#  'have',
#  'skill',
#  'for',
#  'programmers',
#  'data',
#  'scientists',
#  'developers',
#  'many',
#  'Python',
#  'being',
#  'so',
#  'popular',
#  'highly',
#  'demanding',
#  'ranked',
#  'the',
#  'top',
#  'programming',
#  'language',
#  'to',
#  'several',
#  'reports']

# %%
re.findall(r"\b[]\w+",text)
# Out:
# ['one',
#  'of',
#  'the',
#  'powerful',
#  'programming',
#  'to',
#  'popularity',
#  'to',
#  'has',
#  'the',
#  'years',
#  'of',
#  'the',
#  'have',
#  'programmers',
#  'popular',
#  'highly',
#  'the',
#  'top',
#  'programming',
#  'to']

# %%
re.findall(r"[pP]ython",text)
# Out:
# ['Python', 'Python', 'Python', 'Python']

# %%
re.findall(r"\b[^\d\s\W]",text)
# Out:
# ['B',
#  'o',
#  'o',
#  't',
#  'm',
#  'p',
#  'a',
#  'v',
#  'p',
#  'l',
#  'P',
#  'i',
#  'e',
#  't',
#  'l',
#  'a',
#  'i',
#  'w',
#  'u',
#  'a',
#  'd',
#  'I',
#  'p',
#  'a',
#  'd',
#  'i',
#  'i',
#  'e',
#  's',
#  'i',
#  'l',
#  'a',
#  's',
#  'c',
#  't',
#  'g',
#  'D',
#  'f',
#  'P',
#  'd',
#  'h',
#  'i',
#  'b',
#  'i',
#  't',
#  'l',
#  'y',
#  'O',
#  'o',
#  'm',
#  'd',
#  'i',
#  't',
#  'w',
#  'm',
#  'a',
#  'P',
#  'd',
#  'I',
#  'i',
#  'a',
#  'm',
#  'h',
#  's',
#  'f',
#  'p',
#  'd',
#  's',
#  'a',
#  'd',
#  'a',
#  'm',
#  'i',
#  'P',
#  'b',
#  's',
#  'p',
#  'a',
#  'h',
#  'd',
#  'i',
#  'r',
#  'a',
#  't',
#  't',
#  'p',
#  'l',
#  'a',
#  't',
#  's',
#  'r']

# %%
emial= "my mail id is ram@gmail.com"

# %%
re.findall("\w",text)
# Out:
# ['B',
#  'e',
#  'i',
#  'n',
#  'g',
#  'o',
#  'n',
#  'e',
#  'o',
#  'f',
#  't',
#  'h',
#  'e',
#  'm',
#  'o',
#  's',
#  't',
#  'p',
#  'o',
#  'w',
#  'e',
#  'r',
#  'f',
#  'u',
#  'l',
#  'a',
#  'n',
#  'd',
#  'v',
#  'e',
#  'r',
#  's',
#  'a',
#  't',
#  'i',
#  'l',
#  'e',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g',
#  'l',
#  'a',
#  'n',
#  'g',
#  'u',
#  'a',
#  'g',
#  'e',
#  's',
#  'P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  'i',
#  's',
#  'e',
#  'a',
#  's',
#  'y',
#  't',
#  'o',
#  'l',
#  'e',
#  'a',
#  'r',
#  'n',
#  'a',
#  'n',
#  'd',
#  'i',
#  's',
#  'w',
#  'i',
#  'd',
#  'e',
#  'l',
#  'y',
#  'u',
#  's',
#  'e',
#  'd',
#  'a',
#  'm',
#  'o',
#  'n',
#  'g',
#  'd',
#  'e',
#  'v',
#  'e',
#  'l',
#  'o',
#  'p',
#  'e',
#  'r',
#  's',
#  'I',
#  't',
#  's',
#  'p',
#  'o',
#  'p',
#  'u',
#  'l',
#  'a',
#  'r',
#  'i',
#  't',
#  'y',
#  'a',
#  'n',
#  'd',
#  'd',
#  'e',
#  'm',
# ...

# %%
re.findall(r"\w+@\w+.\w+",emial)
# Out:
# ['ram@gmail.com']

# %%
re.findall(r"\w+\.",emial)
# Out:
# ['gmail.']

# %%
re.findall(r"\w+)
# Out:
#   Cell In[1], line 1
#     re.findall(r"\w+)
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import re

# %%
texxt=The 2024 Grammy Awards will dazzle the music industry and fans alike, promising to be a night of extraordinary performances, unexpected wins, and memorable moments. The Grammys are presented by the Recording Academy of the United States for outstanding achievement in music. Trevor Noah, the comedian extraordinaire, will take on hosting duties for the fourth consecutive year, presiding over an impressive 94 categories. Popular names like Taylor Swift, Olivia Rodrigo, Miley Cyrus, Lana Del Rey and Ice Spice own multiple nominations in different categories. This year, the Recording Academy has added three categories: African music performance, alternative jazz album and pop dance recording. The prestigious event will showcase performances by Joni Mitchell, Travis Scott, Olivia Rodrigo, Billie Eilish, Dua Lipa and more. Sibling duo Billie Eilish and Finneas O'Connell kicked off the night on a winning note with the Best Song Written for Visual Media category, they are also the contenders for additional Grammy Awards, including Record and Song of the Year.The 67th Grammy Awards will take place at Los Angeles's Crypto Arena on Sunday, February 4. Follow this blog for the latest updates about the prestigious awards ceremony.READ LESS

Key Events
Key Events

# %%
text="""The 2024 Grammy Awards will dazzle the music industry and fans alike, promising to be a night of extraordinary performances, unexpected wins, and memorable moments. The Grammys are presented by the Recording Academy of the United States for outstanding achievement in music. Trevor Noah, the comedian extraordinaire, will take on hosting duties for the fourth consecutive year, presiding over an impressive 94 categories. Popular names like Taylor Swift, Olivia Rodrigo, Miley Cyrus, Lana Del Rey and Ice Spice own multiple nominations in different categories. This year, the Recording Academy has added three categories: African music performance, alternative jazz album and pop dance recording. The prestigious event will showcase performances by Joni Mitchell, Travis Scott, Olivia Rodrigo, Billie Eilish, Dua Lipa and more. Sibling duo Billie Eilish and Finneas O'Connell kicked off the night on a winning note with the Best Song Written for Visual Media category, they are also the contenders for additional Grammy Awards, including Record and Song of the Year.The 67th Grammy Awards will take place at Los Angeles's Crypto Arena on Sunday, February 4. Follow this blog for the latest updates about the prestigious awards ceremony.READ LESS

Key Events
Key Events
"""

# %%
re.findall(r"\w+",text)
# Out:
# ['The',
#  '2024',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'promising',
#  'to',
#  'be',
#  'a',
#  'night',
#  'of',
#  'extraordinary',
#  'performances',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'presented',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'States',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'presiding',
#  'over',
#  'an',
#  'impressive',
#  '94',
#  'categories',
#  'Popular',
#  'names',
#  'like',
#  'Taylor',
#  'Swift',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'Spice',
#  'own',
#  'multiple',
# ...

# %%
re.findall(r"\b[^pP\W\d]\w+",text)
# Out:
# ['The',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'to',
#  'be',
#  'night',
#  'of',
#  'extraordinary',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'States',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'over',
#  'an',
#  'impressive',
#  'categories',
#  'names',
#  'like',
#  'Taylor',
#  'Swift',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'Spice',
#  'own',
#  'multiple',
#  'nominations',
#  'in',
#  'different',
#  'categories',
#  'This',
#  'year',
#  'the',
#  'Recording',
# ...

# %%
re.findall(r"\b\w+",text)
# Out:
# ['The',
#  '2024',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'promising',
#  'to',
#  'be',
#  'a',
#  'night',
#  'of',
#  'extraordinary',
#  'performances',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'presented',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'States',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'presiding',
#  'over',
#  'an',
#  'impressive',
#  '94',
#  'categories',
#  'Popular',
#  'names',
#  'like',
#  'Taylor',
#  'Swift',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'Spice',
#  'own',
#  'multiple',
# ...

# %%
re.findall(r"\d+",text)
# Out:
# ['2024', '94', '67', '4']

# %%
re.findall("\w+",text)
# Out:
# ['The',
#  '2024',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'promising',
#  'to',
#  'be',
#  'a',
#  'night',
#  'of',
#  'extraordinary',
#  'performances',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'presented',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'States',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'presiding',
#  'over',
#  'an',
#  'impressive',
#  '94',
#  'categories',
#  'Popular',
#  'names',
#  'like',
#  'Taylor',
#  'Swift',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'Spice',
#  'own',
#  'multiple',
# ...

# %%
re.findall(r"\w+",text)
# Out:
# ['The',
#  '2024',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'promising',
#  'to',
#  'be',
#  'a',
#  'night',
#  'of',
#  'extraordinary',
#  'performances',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'presented',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'States',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'presiding',
#  'over',
#  'an',
#  'impressive',
#  '94',
#  'categories',
#  'Popular',
#  'names',
#  'like',
#  'Taylor',
#  'Swift',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'Spice',
#  'own',
#  'multiple',
# ...

# %%
text
# Out:
# "The 2024 Grammy Awards will dazzle the music industry and fans alike, promising to be a night of extraordinary performances, unexpected wins, and memorable moments. The Grammys are presented by the Recording Academy of the United States for outstanding achievement in music. Trevor Noah, the comedian extraordinaire, will take on hosting duties for the fourth consecutive year, presiding over an impressive 94 categories. Popular names like Taylor Swift, Olivia Rodrigo, Miley Cyrus, Lana Del Rey and Ice Spice own multiple nominations in different categories. This year, the Recording Academy has added three categories: African music performance, alternative jazz album and pop dance recording. The prestigious event will showcase performances by Joni Mitchell, Travis Scott, Olivia Rodrigo, Billie Eilish, Dua Lipa and more. Sibling duo Billie Eilish and Finneas O'Connell kicked off the night on a winning note with the Best Song Written for Visual Media category, they are also the contenders
# ...

# %%
re.findall(r"\w+",text)
# Out:
# ['The',
#  '2024',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'promising',
#  'to',
#  'be',
#  'a',
#  'night',
#  'of',
#  'extraordinary',
#  'performances',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'presented',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'States',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'presiding',
#  'over',
#  'an',
#  'impressive',
#  '94',
#  'categories',
#  'Popular',
#  'names',
#  'like',
#  'Taylor',
#  'Swift',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'Spice',
#  'own',
#  'multiple',
# ...

# %%
re.findall(r"\d+",text)
# Out:
# ['2024', '94', '67', '4']

# %%
re.findall(r"\w+",text)
# Out:
# ['The',
#  '2024',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'promising',
#  'to',
#  'be',
#  'a',
#  'night',
#  'of',
#  'extraordinary',
#  'performances',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'presented',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'States',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'presiding',
#  'over',
#  'an',
#  'impressive',
#  '94',
#  'categories',
#  'Popular',
#  'names',
#  'like',
#  'Taylor',
#  'Swift',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'Spice',
#  'own',
#  'multiple',
# ...

# %%
re.findall(r"\W+",text)
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ', ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  '. ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '. ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '. ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ', ',
#  ' ',
#  ', ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '. ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ': ',
#  ' ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '. ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ', ',
#  ' ',
#  ', ',
#  ' ',
#  ', ',
#  ' ',
#  ', ',
#  ' ',
#  ' ',
#  ' ',
#  '. ',
# ...

# %%
re.findall(r"\d+",text)
# Out:
# ['2024', '94', '67', '4']

# %%
re.findall(r"\b",text)
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
re.findall(r"\b[^sS\s\d]\w+",text)
# Out:
# ['The',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'promising',
#  'to',
#  'be',
#  'night',
#  'of',
#  'extraordinary',
#  'performances',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'presented',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'presiding',
#  'over',
#  'an',
#  'impressive',
#  'categories',
#  'Popular',
#  'names',
#  'like',
#  'Taylor',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'own',
#  'multiple',
#  'nominations',
#  'in',
#  'different',
#  'categories',
#  'This',
# ...

# %%
mail="mayalurinani97@gmail.com"

# %%
re.findall(r"\W\w+.\w+",mail)
# Out:
# ['@gmail.com']

# %%
tex="""A small kid who used to play in the local cricket teams to now the captain of Indian cricket team, the journey of self-assured, talented Virat Kohli is not only long but also quite inspiring. The Indian International Cricketer is known to be among the best batsman in the present era for his dependable and impressive batting style. He has managed to bring home many victorious awards single-handedly. His craze for cricket is not something new. He had keen interest and potential in this game at a quiet early age and took up the bat at the age of just 3 years."""

# %% [markdown]
# \w--aplphanumeric values
# \W--special characters
# \d--digits
# \b--boundary
# \s--spaces

# %%
import re
re.findall(r"\w+",tex)
# Out:
# ['A',
#  'small',
#  'kid',
#  'who',
#  'used',
#  'to',
#  'play',
#  'in',
#  'the',
#  'local',
#  'cricket',
#  'teams',
#  'to',
#  'now',
#  'the',
#  'captain',
#  'of',
#  'Indian',
#  'cricket',
#  'team',
#  'the',
#  'journey',
#  'of',
#  'self',
#  'assured',
#  'talented',
#  'Virat',
#  'Kohli',
#  'is',
#  'not',
#  'only',
#  'long',
#  'but',
#  'also',
#  'quite',
#  'inspiring',
#  'The',
#  'Indian',
#  'International',
#  'Cricketer',
#  'is',
#  'known',
#  'to',
#  'be',
#  'among',
#  'the',
#  'best',
#  'batsman',
#  'in',
#  'the',
#  'present',
#  'era',
#  'for',
#  'his',
#  'dependable',
#  'and',
#  'impressive',
#  'batting',
#  'style',
#  'He',
#  'has',
#  'managed',
#  'to',
#  'bring',
#  'home',
#  'many',
#  'victorious',
#  'awards',
#  'single',
#  'handedly',
#  'His',
#  'craze',
#  'for',
#  'cricket',
#  'is',
#  'not',
#  'something',
#  'new',
#  'He',
#  'had',
#  'keen',
#  'interest',
#  'and',
#  'potential',
#  'in',
#  'this',
# ...

# %%
re.findall(r"\d\d",text)
# Out:
# ['20', '24', '94', '67']

# %%
text
# Out:
# "The 2024 Grammy Awards will dazzle the music industry and fans alike, promising to be a night of extraordinary performances, unexpected wins, and memorable moments. The Grammys are presented by the Recording Academy of the United States for outstanding achievement in music. Trevor Noah, the comedian extraordinaire, will take on hosting duties for the fourth consecutive year, presiding over an impressive 94 categories. Popular names like Taylor Swift, Olivia Rodrigo, Miley Cyrus, Lana Del Rey and Ice Spice own multiple nominations in different categories. This year, the Recording Academy has added three categories: African music performance, alternative jazz album and pop dance recording. The prestigious event will showcase performances by Joni Mitchell, Travis Scott, Olivia Rodrigo, Billie Eilish, Dua Lipa and more. Sibling duo Billie Eilish and Finneas O'Connell kicked off the night on a winning note with the Best Song Written for Visual Media category, they are also the contenders
# ...

# %%
re.findall(r"\s",text)
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
# ...

# %%
re.findall(r"\b",text)
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
re.findall(r"\b[^p\s\d]\w+",text)
# Out:
# ['The',
#  'Grammy',
#  'Awards',
#  'will',
#  'dazzle',
#  'the',
#  'music',
#  'industry',
#  'and',
#  'fans',
#  'alike',
#  'to',
#  'be',
#  'night',
#  'of',
#  'extraordinary',
#  'unexpected',
#  'wins',
#  'and',
#  'memorable',
#  'moments',
#  'The',
#  'Grammys',
#  'are',
#  'by',
#  'the',
#  'Recording',
#  'Academy',
#  'of',
#  'the',
#  'United',
#  'States',
#  'for',
#  'outstanding',
#  'achievement',
#  'in',
#  'music',
#  'Trevor',
#  'Noah',
#  'the',
#  'comedian',
#  'extraordinaire',
#  'will',
#  'take',
#  'on',
#  'hosting',
#  'duties',
#  'for',
#  'the',
#  'fourth',
#  'consecutive',
#  'year',
#  'over',
#  'an',
#  'impressive',
#  'categories',
#  'Popular',
#  'names',
#  'like',
#  'Taylor',
#  'Swift',
#  'Olivia',
#  'Rodrigo',
#  'Miley',
#  'Cyrus',
#  'Lana',
#  'Del',
#  'Rey',
#  'and',
#  'Ice',
#  'Spice',
#  'own',
#  'multiple',
#  'nominations',
#  'in',
#  'different',
#  'categories',
#  'This',
#  'year',
#  'the',
# ...

# %%
re.findall(r"")

# %%
text
# Out:
# "The 2024 Grammy Awards will dazzle the music industry and fans alike, promising to be a night of extraordinary performances, unexpected wins, and memorable moments. The Grammys are presented by the Recording Academy of the United States for outstanding achievement in music. Trevor Noah, the comedian extraordinaire, will take on hosting duties for the fourth consecutive year, presiding over an impressive 94 categories. Popular names like Taylor Swift, Olivia Rodrigo, Miley Cyrus, Lana Del Rey and Ice Spice own multiple nominations in different categories. This year, the Recording Academy has added three categories: African music performance, alternative jazz album and pop dance recording. The prestigious event will showcase performances by Joni Mitchell, Travis Scott, Olivia Rodrigo, Billie Eilish, Dua Lipa and more. Sibling duo Billie Eilish and Finneas O'Connell kicked off the night on a winning note with the Best Song Written for Visual Media category, they are also the contenders
# ...

# %%
email="sahithi@gmail.com and srinath@yahoo.com"

# %%
re.findall(r"\w+\W\w+\.\w+",email)
# Out:
# ['sahithi@gmail.com', 'srinath@yahoo.com']

# %%
re.findall(r"@\w+.\w+",email)
# Out:
# ['@gmail.com', '@yahoo.com']

# %%
re.findall(r"\w+@\w+\.\w+",email)
# Out:
# ['sahithi@gmail.com', 'srinath@yahoo.com']

# %%
text= "Innomatics is 08098404&&&one of the best 450285029850 institute%%% for Data Science????"

# %%
re.findall(r"\w+",text)
# Out:
# ['Innomatics',
#  'is',
#  '08098404',
#  'one',
#  'of',
#  'the',
#  'best',
#  '450285029850',
#  'institute',
#  'for',
#  'Data',
#  'Science']

# %%
re.findall(r"")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 re.findall(r"")
#
# TypeError: findall() missing 1 required positional argument: 'string'

# %%
import re

# %%
text= """IPv6 Address. . . . . . . . . . . : 2409:40f0:1148:427d:d84b:2f19:c846:b4aa
   Temporary IPv6 Address. . . . . . : 2409:40f0:1148:427d:45d3:9299:7503:6cf
   Link-local IPv6 Address . . . . . : fe80::c3c7:5613:6620:92f0%10
   IPv4 Address. . . . . . . . . . . : 192.168.154.43
   Subnet Mask . . . . . . . . . . . : 255.255.255.0
   Default Gateway . . . . . . . . . : fe80::5c5e:c4ff:fe3a:2f42%10"""

# %%
tex="""Link-local IPv6 Address . . . . . : fe80::e6e8:d725:63d5:3141%16
   IPv4 Address. . . . . . . . . . . : 192.168.0.67
   Subnet Mask . . . . . . . . . . . : 255.255.255.0
   Default Gateway . . . . . . . . . : 192.168.0.1"""

# %%
re.findall(r"\d+\.\d+\.\d+\.\d+",tex)
# Out:
# ['192.168.0.67', '255.255.255.0', '192.168.0.1']

# %%
mobile="my mobile number is 9848022338 and 090909000 and 90909 90876"

# %%
re.findall(r"[6-9]{1}[0-9]{9}",mobile)
# Out:
# ['9848022338']

# %%
re.findall(r"[6-9]{1}\d{9}",mobile)
# Out:
# ['9848022338']

# %%
re.findall(r"[6-9]{1}[0-9]{4}\s[0-9]{5}",mobile)
# Out:
# ['90909 90876']

# %%
re.findall(r"[6-9]{1}\d+{4}\s\d+{5}",mobile)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 re.findall(r"[6-9]{1}\d+{4}\s\d+{5}",mobile)
#
# File ~\anaconda3\Lib\re\__init__.py:216, in findall(pattern, string, flags)
#     208 def findall(pattern, string, flags=0):
#     209     """Return a list of all non-overlapping matches in the string.
#     210
#     211     If one or more capturing groups are present in the pattern, return
#    (...)
#     214
#     215     Empty matches are included in the result."""
# --> 216     return _compile(pattern, flags).findall(string)
#
# File ~\anaconda3\Lib\re\__init__.py:294, in _compile(pattern, flags)
#     288     import warnings
#     289     warnings.warn("The re.TEMPLATE/re.T flag is deprecated "
#     290               "as it is an undocumented flag "
#     291               "without an obvious purpose. "
#     292               "Don't use it.",
# ...

# %%
mob="My mobile number is 9848022338 and 2343411109 and 98480 22338 and 984 802 2338 and +91-9848022338 and 09848022338"

# %%
re.findall(r"\+\d+\-[6-9]{1}\d{9}",mob)
# Out:
# ['+91-9848022338']

# %%
re.findall(r"0[6-9]{1}\d{9}",mob)
# Out:
# ['09848022338']

# %% [markdown]
# ###reviews

# %%
reviws="""good:Movie was awesome
bad:worest movie
good:worth watch
bad:waste of money
good:fatastic
bad:not upto the mark
good:worth watch
bad:waste of money
good:fatastic
bad:not upto the mark"""

# %%
re.findall(r"\b[g]\w+\W\w+\s\w+\w+\s\w+",reviws)
# Out:
# ['good:Movie was awesome', 'good:worth watch\nbad', 'good:worth watch\nbad']

# %%
reviws
# Out:
# 'good:Movie was awesome\nbad:worest movie\ngood:worth watch\nbad:waste of money\ngood:fatastic\nbad:not upto the mark\ngood:worth watch\nbad:waste of money\ngood:fatastic\nbad:not upto the mark'

# %%
re.findall(r"bad:(.*)\n",reviws)
# Out:
# ['worest movie', 'waste of money', 'not upto the mark', 'waste of money']

# %%
a=12345
re.findall(r"3",str
           (a))
# Out:
# ['3']

# %%
text="python is an object orientied programming language"

# %%
text
# Out:
# 'python is an object orientied programming language'

# %%
res=re.match(r"python",text)

# %%
res
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
res.group()
# Out:
# 'python'

# %%
res.start()
# Out:
# 0

# %%
res.end()
# Out:
# 6

# %%
res=re.search("object",text)

# %%
res.group()
# Out:
# 'object'

# %%
res.start()
# Out:
# 13

# %%
text="innomatics is &&one of the best institute%%% for data science????"
re.sub(r"[&%?*^$#]","",text)
# Out:
# 'innomatics is one of the best institute for data science'

# %%
mob="My mobile number is 9848022338 and 2343411109 and 98480 22338 and 984 802 2338 and +91-9848022338 and 09848022338"

# %%
import re
re.findall(r"[6-9]{1}\d{4}\s\d{5}",mob)
# Out:
# ['98480 22338']

# %%
re.findall(r"\+91-[6-9]{1}\d{9}",mob)
# Out:
# ['+91-9848022338']

# %%
re.findall(r"[0]{1}\d{10}",mob)
# Out:
# ['09848022338']

# %%
text="""Virat Kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] ⓘ; born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-fast bowler. He currently represents Royal Challengers Bangalore in the IPL and Delhi in domestic cricket. Kohli is widely regarded as one of the greatest batsmen in the history of cricket and the best of the 21st century.[3] He holds the record as the highest run-scorer in T20I and IPL, ranks third in ODI, and stands as the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and stands second in the list of most international centuries scored. Kohli was a member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, and captained India to win the ICC Test mace three consecutive times in 2017, 2018, and 2019.[5]

"""

# %%
text
# Out:
# 'Virat Kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] ⓘ; born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-fast bowler. He currently represents Royal Challengers Bangalore in the IPL and Delhi in domestic cricket. Kohli is widely regarded as one of the greatest batsmen in the history of cricket and the best of the 21st century.[3] He holds the record as the highest run-scorer in T20I and IPL, ranks third in ODI, and stands as the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and stands second in the list of most international centuries scored. Kohli was a member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, and captained India to win the ICC Test mace three consecutive times in 2017, 2018, and 2019.[5]\n\n'

# %%
re.findall(r"\d+",text)
# Out:
# ['5',
#  '1988',
#  '21',
#  '3',
#  '20',
#  '4',
#  '2011',
#  '2013',
#  '2017',
#  '2018',
#  '2019',
#  '5']

# %%
re.findall(r"2017",text)
# Out:
# ['2017']

# %%
re.sub("2017","2024",text)
# Out:
# 'Virat Kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] ⓘ; born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-fast bowler. He currently represents Royal Challengers Bangalore in the IPL and Delhi in domestic cricket. Kohli is widely regarded as one of the greatest batsmen in the history of cricket and the best of the 21st century.[3] He holds the record as the highest run-scorer in T20I and IPL, ranks third in ODI, and stands as the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and stands second in the list of most international centuries scored. Kohli was a member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, and captained India to win the ICC Test mace three consecutive times in 2024, 2018, and 2019.[5]\n\n'

# %%
re.sub("virat kohli","virat",text)
# Out:
# 'Virat Kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] ⓘ; born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-fast bowler. He currently represents Royal Challengers Bangalore in the IPL and Delhi in domestic cricket. Kohli is widely regarded as one of the greatest batsmen in the history of cricket and the best of the 21st century.[3] He holds the record as the highest run-scorer in T20I and IPL, ranks third in ODI, and stands as the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and stands second in the list of most international centuries scored. Kohli was a member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, and captained India to win the ICC Test mace three consecutive times in 2017, 2018, and 2019.[5]\n\n'

# %%
re.findall(r"\b[Virat Kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] ⓘ; born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-fast bowler. He currently represents Royal Challengers Bangalore in the IPL and Delhi in domestic cricket. Kohli is widely regarded as one of the greatest batsmen in the history of cricket and the best of the 21st century.[3] He holds the record as the highest run-scorer in T20I and IPL, ranks third in ODI, and stands as the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and stands second in the list of most international centuries scored. Kohli was a member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, and captained India to win the ICC Test mace three consecutive times in 2017, 2018, and 2019.[5]

]\w+",text)
# Out:
# []

# %%
re.findall(r"\b[Vk]\w+",text)
# Out:
# ['Virat']

# %%
re.match(r"virat",text)

# %%
re.sub("Virat","at",text)
# Out:
# 'at Kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] ⓘ; born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-fast bowler. He currently represents Royal Challengers Bangalore in the IPL and Delhi in domestic cricket. Kohli is widely regarded as one of the greatest batsmen in the history of cricket and the best of the 21st century.[3] He holds the record as the highest run-scorer in T20I and IPL, ranks third in ODI, and stands as the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and stands second in the list of most international centuries scored. Kohli was a member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, and captained India to win the ICC Test mace three consecutive times in 2017, 2018, and 2019.[5]\n\n'

# %%
text
# Out:
# 'Virat Kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] ⓘ; born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-fast bowler. He currently represents Royal Challengers Bangalore in the IPL and Delhi in domestic cricket. Kohli is widely regarded as one of the greatest batsmen in the history of cricket and the best of the 21st century.[3] He holds the record as the highest run-scorer in T20I and IPL, ranks third in ODI, and stands as the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and stands second in the list of most international centuries scored. Kohli was a member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, and captained India to win the ICC Test mace three consecutive times in 2017, 2018, and 2019.[5]\n\n'

# %%
re.sub("Virat Kohli","kohli",text)
# Out:
# 'kohli (Hindi pronunciation: [ʋɪˈɾɑːʈ ˈkoːɦli] ⓘ; born 5 November 1988) is an Indian international cricketer and the former captain of the Indian national cricket team. He is a right-handed batsman and an occasional medium-fast bowler. He currently represents Royal Challengers Bangalore in the IPL and Delhi in domestic cricket. Kohli is widely regarded as one of the greatest batsmen in the history of cricket and the best of the 21st century.[3] He holds the record as the highest run-scorer in T20I and IPL, ranks third in ODI, and stands as the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and stands second in the list of most international centuries scored. Kohli was a member of the Indian team that won the 2011 Cricket World Cup, 2013 ICC Champions Trophy, and captained India to win the ICC Test mace three consecutive times in 2017, 2018, and 2019.[5]\n\n'
